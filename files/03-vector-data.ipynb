# %%
import geopandas as gpd

# %%
cropfield = gpd.read_file("data/brpgewaspercelen_definitief_2020_small.gpkg")

# %%
cropfield
# Out:
#        category                                         gewas  gewascode  \
# 0      Grasland                            Grasland, blijvend        265
# 1      Grasland                            Grasland, blijvend        265
# 2      Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331
# 3      Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331
# 4      Grasland                            Grasland, blijvend        265
# ...         ...                                           ...        ...
# 22026  Grasland                            Grasland, blijvend        265
# 22027  Grasland                            Grasland, blijvend        265
# 22028  Grasland                            Grasland, blijvend        265
# 22029  Bouwland                                   Maïs, snij-        259
# 22030  Grasland                            Grasland, blijvend        265
#
#        jaar      status                                           geometry
# ...

# %%
gpd.read_file?
# Out:
# Signature:
# gpd.read_file(
#     filename,
#     bbox=None,
#     mask=None,
#     rows=None,
#     engine=None,
#     **kwargs,
# )
# Docstring:
# Returns a GeoDataFrame from a file or URL.
#
# .. versionadded:: 0.7.0 mask, rows
#
# Parameters
# ----------
# filename : str, path object or file-like object
#     Either the absolute or relative path to the file or URL to
#     be opened, or any object with a read() method (such as an open file
#     or StringIO)
# bbox : tuple | GeoDataFrame or GeoSeries | shapely Geometry, default None
#     Filter features by given bounding box, GeoSeries, GeoDataFrame or a shapely
#     geometry. With engine="fiona", CRS mis-matches are resolved if given a GeoSeries
#     or GeoDataFrame. With engine="pyogrio", bbox must be in the same CRS as the
#     dataset. Tuple is (minx, miny, maxx, maxy) to match the bounds property of
#     shapely geometry objects. Cannot be used with mask.
# ...

# %%
cropfield = gpd.read_file("data/brpgewaspercelen_definitief_2020_small.gpkg", rows=10)

# %%
cropfield
# Out:
#    category                                         gewas  gewascode  jaar  \
# 0  Grasland                            Grasland, blijvend        265  2020
# 1  Grasland                            Grasland, blijvend        265  2020
# 2  Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331  2020
# 3  Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331  2020
# 4  Grasland                            Grasland, blijvend        265  2020
# 5  Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331  2020
# 6  Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331  2020
# 7  Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331  2020
# 8  Grasland                            Grasland, blijvend        265  2020
# 9  Grasland                            Grasland, blijvend        265  2020
#
#        status                                           geometry
# 0  Definitief  POLYGON ((117626.809 505287.535, 117622.930 50...
# ...

# %%
cropfield.crs
# Out:
# <Derived Projected CRS: EPSG:28992>
# Name: Amersfoort / RD New
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: Netherlands - onshore, including Waddenzee, Dutch Wadden Islands and 12-mile offshore coastal zone.
# - bounds: (3.2, 50.75, 7.22, 53.7)
# Coordinate Operation:
# - name: RD New
# - method: Oblique Stereographic
# Datum: Amersfoort
# - Ellipsoid: Bessel 1841
# - Prime Meridian: Greenwich

# %%
minx, miny, maxx, maxy = (110_000, 475_000, 140_000, 500_000)
bbox = (minx, miny, maxx, maxy)
bbox
# Out:
# (110000, 475000, 140000, 500000)

# %%
cropfield = gpd.read_file("data/brpgewaspercelen_definitief_2020_small.gpkg", bbox=bbox)

# %%
cropfield
# Out:
#        category                                         gewas  gewascode  \
# 0      Grasland                            Grasland, blijvend        265
# 1      Grasland                            Grasland, blijvend        265
# 2      Grasland                            Grasland, blijvend        265
# 3      Grasland                            Grasland, blijvend        265
# 4      Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331
# ...         ...                                           ...        ...
# 11778  Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331
# 11779  Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331
# 11780  Grasland                            Grasland, blijvend        265
# 11781  Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331
# 11782  Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331
#
#        jaar      status                                           geometry
# ...

# %%
test_data = gpd.read_file("https://figshare.com/ndownloader/files/37729413", rows=10)

# %%
test_data
# Out:
#        category                                         gewas  gewascode  \
# 0      Grasland                            Grasland, blijvend        265
# 1      Grasland                            Grasland, blijvend        265
# 2      Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331
# 3      Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331
# 4      Grasland                            Grasland, blijvend        265
# ...         ...                                           ...        ...
# 22026  Grasland                            Grasland, blijvend        265
# 22027  Grasland                            Grasland, blijvend        265
# 22028  Grasland                            Grasland, blijvend        265
# 22029  Bouwland                                   Maïs, snij-        259
# 22030  Grasland                            Grasland, blijvend        265
#
#        jaar      status                                           geometry
# ...

# %%
type(cropfield)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
cropfield.type
# Out:
# 0        Polygon
# 1        Polygon
# 2        Polygon
# 3        Polygon
# 4        Polygon
#           ...
# 11778    Polygon
# 11779    Polygon
# 11780    Polygon
# 11781    Polygon
# 11782    Polygon
# Length: 11783, dtype: object

# %%
cropfield.type.unique()
# Out:
# array(['Polygon'], dtype=object)

# %%
cropfield.crs
# Out:
# <Derived Projected CRS: EPSG:28992>
# Name: Amersfoort / RD New
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: Netherlands - onshore, including Waddenzee, Dutch Wadden Islands and 12-mile offshore coastal zone.
# - bounds: (3.2, 50.75, 7.22, 53.7)
# Coordinate Operation:
# - name: RD New
# - method: Oblique Stereographic
# Datum: Amersfoort
# - Ellipsoid: Bessel 1841
# - Prime Meridian: Greenwich

# %%
cropfield.total_bounds
# Out:
# array([109222.03325 , 474354.619875, 140295.122125, 500782.531   ])

# %%
cropfield.plot()
# Out:
# <AxesSubplot: >

# %%
xmin, xmax = (120_000, 135_000)
ymin, ymax = (485_000, 500_000)

# %%
cropfield = cropfield.cx[xmin:xmax, ymin:ymax]

# %%
cropfield
# Out:
#        category                                         gewas  gewascode  \
# 0      Grasland                            Grasland, blijvend        265
# 1      Grasland                            Grasland, blijvend        265
# 2      Grasland                            Grasland, blijvend        265
# 3      Grasland                            Grasland, blijvend        265
# 4      Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331
# ...         ...                                           ...        ...
# 11778  Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331
# 11779  Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331
# 11780  Grasland                            Grasland, blijvend        265
# 11781  Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331
# 11782  Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331
#
#        jaar      status                                           geometry
# ...

# %%
cropfield.plot()
# Out:
# <AxesSubplot: >

# %%
cropfield.to_file("cropfield.shp")

# %%
waterways = gpd.read_file("data/status_vaarweg.zip")

# %%
waterways.type.unique()
# Out:
# array(['LineString'], dtype=object)

# %%
waterways.geom_type
# Out:
# 0     LineString
# 1     LineString
# 2     LineString
# 3     LineString
# 4     LineString
#          ...
# 86    LineString
# 87    LineString
# 88    LineString
# 89    LineString
# 90    LineString
# Length: 91, dtype: object

# %%
waterways.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
waterways.total_bounds
# Out:
# array([50.7916,  3.1626, 53.6161,  7.0121])

# %%
waterways.plot()
# Out:
# <AxesSubplot: >

# %%
print(waterways["geometry"][0])
# Out:
# LINESTRING (52.418099999 4.84059999900001, 52.420699999 4.84089999999998, 52.4219 4.840300001, 52.422899999 4.83900000199998, 52.426899999 4.83529999899997, 52.4278 4.83439999799998, 52.431200001 4.83210000000003, 52.431699999 4.831700001, 52.4355 4.82869999899998, 52.4366 4.8279, 52.4388 4.82629999900001, 52.440499999 4.82470000199999, 52.441 4.824299999, 52.4461 4.8211, 52.447500002 4.82070000099998, 52.4494 4.821199998, 52.450599998 4.82059999900002, 52.4518 4.81909999999999, 52.454500001 4.813499998, 52.454999998 4.81270000000001, 52.455699999 4.81219999899997, 52.457699999 4.81260000200001, 52.459100001 4.81289999900002, 52.460999999 4.81280000100003, 52.463 4.81260000200001, 52.4639 4.81360000000001, 52.465100002 4.816300001, 52.465599999 4.817299999, 52.466200002 4.81799999999998, 52.466699999 4.81819999999999, 52.4672 4.81779999999998, 52.467599999 4.81700000199999, 52.468699999 4.81490000000002, 52.469300002 4.81399999899998, 52.4703 4.81329999899998, 52.471000001 4.81329999
# ...

# %%
waterways
# Out:
#     OBJECTID VRT_CODE                                            VRTNAAM  \
# 0        7.0      236  Zaan, Tap- of Tochtsloot, Markervaart en Alkma...
# 1        8.0      206                                          Oude Rijn
# 2        9.0      571                      Scheepvaartroute Scheveningen
# 3       10.0      406  Vaarwater naar Emden, Gaatje Bocht, Oostfriesc...
# 4       11.0      229  Vaarweg vanaf het IJmeer via de Randmeren naar...
# ..       ...      ...                                                ...
# 86      87.0     124c                                      Beatrixkanaal
# 87      88.0      228                       Eem en havens van Amersfoort
# 88      89.0     102m                                          Breeddiep
# 89      90.0      270       Gouwe, Gouwekanaal en voorhaven Julianasluis
# 90      91.0      102           Nieuwe Maas, Nieuwe Waterweg en Maasmond
#
#    HAVEN_VAAR  MEETPUNT_B  MEETPUNT_E TRAJECTLEN STATUS        TOEVOEGING  \
# ...

# %%
print(cropfield["geometry"][0])
# Out:
# POLYGON ((120154.93212499836 495930.341124998, 120159.24987500161 495931.294250001, 120160.8200000003 495936.45324999926, 120161.51237500084 495938.16174999933, 120160.2713750005 495938.38749999844, 120159.0807499997 495939.71037499886, 120157.75775000085 495947.6478749995, 120147.70362500098 496018.82075000176, 120137.64950000124 496095.9468750008, 120127.46299999951 496164.7385, 120123.49424999952 496194.3718749999, 120123.49424999955 496195.9593750014, 120127.57950000095 496197.55337500066, 120127.13399999961 496200.5156250005, 120111.68212499839 496292.8278750004, 120104.10574999824 496339.4825000046, 120102.21175000074 496344.566625, 120100.21099999922 496354.47612500016, 120100.2092499994 496354.4892500016, 120096.64124999942 496381.5626249989, 120096.33837499842 496397.9117500016, 120096.64124999942 496423.646625001, 120096.6412499994 496447.1107500032, 120096.79262499881 496459.67537499906, 120097.04349999879 496461.8191250011, 120098.45775000009 496473.90525000176, 120106.09
# ...

# %%
gdf['coordinates']).map(lambda polygon: shapely.ops.transform(lambda x, y: (y, x), polygon))

# %%
import shapely
def flip(geometry):
    return shapely.ops.transform(lambda x, y: (y, x), geometry)

# %%
type(waterways)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# waterways.apply(flip)

# %%
waterways['geometry'] = waterways['geometry'].apply(flip)

# %%
waterways.plot()
# Out:
# <AxesSubplot: >

# %%
waterways.to_file('waterways_corrected.shp')
